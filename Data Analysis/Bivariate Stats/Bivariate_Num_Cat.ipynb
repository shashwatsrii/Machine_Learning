# %%
from scipy import stats
import statistics as stat

edu_PartialHighSchool = [30000,10000,10000,20000,70000,30000,10000,20000,10000,30000]
edu_HighSchool = [20000,30000,60000,20000,40000,60000,60000]
edu_PartialCollege = [60000,40000,30000,130000,60000,40000]
edu_Bachelors = [40000,20000,90000,120000,60000,130000,20000,100000,80000,30000,100000,120000]
edu_Graduate = [160000,50000,80000,30000,40000,80000,130000,100000,130000,50000,130000]

print("Partial High School : "+ str(int(stat.mean(edu_PartialHighSchool))))
print("High School : "+ str(int(stat.mean(edu_HighSchool))))
print("Partial College : "+ str(int(stat.mean(edu_PartialCollege))))
print("Bachelors : "+ str(int(stat.mean(edu_Bachelors))))
print("Graduate : "+ str(int(stat.mean(edu_Graduate))))
# Out:
# Partial High School : 24000
# High School : 41428
# Partial College : 60000
# Bachelors : 75833
# Graduate : 89090

# %%
t,p = stats.ttest_ind(edu_PartialHighSchool, edu_HighSchool)
print(f"T-value :{t}")
print(f"p-value :{p}")
# Out:
# T-value :-1.9131753750607223
# p-value :0.07500898731578687

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.distplot(edu_PartialHighSchool, label= "Partial High School")
sns.distplot(edu_HighSchool, label= "High School")
sns.distplot(edu_Bachelors, label= "bachelors")
sns.distplot(edu_PartialCollege, label= "partial College")
sns.distplot(edu_Graduate, label= "graduate")
plt.legend()
plt.show()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_12916\476205435.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(edu_PartialHighSchool, label= "Partial High School")
# C:\Users\HP\AppData\Local\Temp\ipykernel_12916\476205435.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(edu_HighSchool, label= "High School")
# C:\Users\HP\AppData\Local\Temp\ipykernel_12916\476205435.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(edu_Bachelors, label= "bachelors")
# C:\Users\HP\AppData\Local\Temp\ipykernel_12916\476205435.py:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(edu_PartialCollege, label= "partial College")
# C:\Users\HP\AppData\Local\Temp\ipykernel_12916\476205435.py:7: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(edu_Graduate, label= "graduate")

# %%
f,p = stats.f_oneway(edu_Bachelors, edu_Graduate, edu_HighSchool,edu_PartialHighSchool,edu_PartialCollege)
print(f"F-value :{f}")
print(f"p-value :{p}")
# Out:
# F-value :5.778065095961635
# p-value :0.0008781084858501964

# %%
import pandas as pd

df = pd.read_csv("https://www.ishelp.info/data/insurance.csv")
df.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
sns.histplot(data = df, x="charges", hue="smoker", kde=True);

# %%
smoker_yes = df[df['smoker']=='yes']
smoker_no = df[df['smoker']=='no']
t,p = stats.ttest_ind(smoker_yes['charges'],smoker_no['charges'])
print(f"T-value :{t}")
print(f"p-value :{p}")
# Out:
# T-value :46.66492117272371
# p-value :8.271435842179102e-283

# %%
features = 'region'
label = 'charges'
def anova(feature, label):
    grouped_values = []
    groups = df[features].unique()
    for group in groups:
        grouped_values.append(df[df[features]==group][label])
    grouped_values


    print(stats.f_oneway(*grouped_values))

# %%
anova('region','charges')
# Out:
# F_onewayResult(statistic=2.96962669358912, pvalue=0.0308933560705201)
