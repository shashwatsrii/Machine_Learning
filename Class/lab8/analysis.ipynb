# %%
import pandas as pd

# %%
data= pd.read_csv("Tweets_Test_Data.csv", encoding=True)
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# c:\Users\HP\OneDrive\Desktop\Machine_Learning\Class\lab8\analysis.ipynb Cell 2 in 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/HP/OneDrive/Desktop/Machine_Learning/Class/lab8/analysis.ipynb#W1sZmlsZQ%3D%3D?line=0'>1</a> data= pd.read_csv("Tweets_Test_Data.csv")
#
# ...

# %%
data.head()
