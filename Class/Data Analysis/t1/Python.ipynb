# %%
# Loading Python Libraries
import numpy as np
import pandas as pd
import scipy as sp
import matplotlib as mpl
import seaborn as sns

# %%
# Reading data using Pandas

df = pd.read_csv("../matches.csv")

# %%
df.head()
# Out:
#    id  season       city        date                        team1
# 0   1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad  \
# 1   2    2017       Pune  2017-04-06               Mumbai Indians
# 2   3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3   4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4   5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field  \
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs
# ...

# %%
df.head(10)
# Out:
#    id  season       city        date                        team1
# 0   1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad  \
# 1   2    2017       Pune  2017-04-06               Mumbai Indians
# 2   3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3   4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4   5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
# 5   6    2017  Hyderabad  2017-04-09                Gujarat Lions
# 6   7    2017     Mumbai  2017-04-09        Kolkata Knight Riders
# 7   8    2017     Indore  2017-04-10  Royal Challengers Bangalore
# 8   9    2017       Pune  2017-04-11             Delhi Daredevils
# 9  10    2017     Mumbai  2017-04-12          Sunrisers Hyderabad
#
#                          team2                  toss_winner toss_decision
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field  \
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# ...

# %%
# Checking Datatypes for the dataframe

print(df['season'].dtype)
print(df['date'].dtype)
print(df['dl_applied'].dtype)
print(df['venue'].dtype)
print("----------------------------------------------------------------")
print(df.dtypes)
# Out:
# int64
# object
# int64
# object
# ----------------------------------------------------------------
# id                   int64
# season               int64
# city                object
# date                object
# team1               object
# team2               object
# toss_winner         object
# toss_decision       object
# result              object
# dl_applied           int64
# winner              object
# win_by_runs          int64
# win_by_wickets       int64
# player_of_match     object
# venue               object
# umpire1             object
# umpire2             object
# umpire3            float64
# dtype: object

# %%
# Dataframe Attributes
print(df.dtypes)
# Out:
# id                   int64
# season               int64
# city                object
# date                object
# team1               object
# team2               object
# toss_winner         object
# toss_decision       object
# result              object
# dl_applied           int64
# winner              object
# win_by_runs          int64
# win_by_wickets       int64
# player_of_match     object
# venue               object
# umpire1             object
# umpire2             object
# umpire3            float64
# dtype: object

# %%
print(df.columns)
# Out:
# Index(['id', 'season', 'city', 'date', 'team1', 'team2', 'toss_winner',
#        'toss_decision', 'result', 'dl_applied', 'winner', 'win_by_runs',
#        'win_by_wickets', 'player_of_match', 'venue', 'umpire1', 'umpire2',
#        'umpire3'],
#       dtype='object')

# %%
print(df.axes)
# Out:
# [RangeIndex(start=0, stop=636, step=1), Index(['id', 'season', 'city', 'date', 'team1', 'team2', 'toss_winner',
#        'toss_decision', 'result', 'dl_applied', 'winner', 'win_by_runs',
#        'win_by_wickets', 'player_of_match', 'venue', 'umpire1', 'umpire2',
#        'umpire3'],
#       dtype='object')]

# %%
print(df.ndim)
# Out:
# 2

# %%
print(df.shape)
# Out:
# (636, 18)

# %%
print(df.size)
# Out:
# 11448

# %%
print(df.values)
# Out:
# [[1 2017 'Hyderabad' ... 'AY Dandekar' 'NJ Llong' nan]
#  [2 2017 'Pune' ... 'A Nand Kishore' 'S Ravi' nan]
#  [3 2017 'Rajkot' ... 'Nitin Menon' 'CK Nandan' nan]
#  ...
#  [634 2016 'Delhi' ... 'M Erasmus' 'C Shamshuddin' nan]
#  [635 2016 'Delhi' ... 'M Erasmus' 'CK Nandan' nan]
#  [636 2016 'Bangalore' ... 'HDPK Dharmasena' 'BNJ Oxenford' nan]]

# %%
# Dataframe Methods
df.describe()
# Out:
#                id       season  dl_applied  win_by_runs  win_by_wickets
# count  636.000000   636.000000  636.000000   636.000000      636.000000  \
# mean   318.500000  2012.490566    0.025157    13.682390        3.372642
# std    183.741666     2.773026    0.156726    23.908877        3.420338
# min      1.000000  2008.000000    0.000000     0.000000        0.000000
# 25%    159.750000  2010.000000    0.000000     0.000000        0.000000
# 50%    318.500000  2012.000000    0.000000     0.000000        4.000000
# 75%    477.250000  2015.000000    0.000000    20.000000        7.000000
# max    636.000000  2017.000000    1.000000   146.000000       10.000000
#
#        umpire3
# count      0.0
# mean       NaN
# std        NaN
# min        NaN
# 25%        NaN
# 50%        NaN
# 75%        NaN
# max        NaN

# %%
df['season'].max()
# Out:
# 2017

# %%
df['season'].median()
# Out:
# 2012.0

# %%
df.sample(5)
# Out:
#       id  season       city        date                  team1
# 469  470    2014        NaN  2014-04-25         Mumbai Indians  \
# 5      6    2017  Hyderabad  2017-04-09          Gujarat Lions
# 111  112    2008    Kolkata  2008-05-25        Kings XI Punjab
# 59    60    2008  Bangalore  2008-04-18  Kolkata Knight Riders
# 630  631    2016    Kolkata  2016-05-22  Kolkata Knight Riders
#
#                            team2                  toss_winner toss_decision
# 469          Chennai Super Kings               Mumbai Indians           bat  \
# 5            Sunrisers Hyderabad          Sunrisers Hyderabad         field
# 111        Kolkata Knight Riders              Kings XI Punjab           bat
# 59   Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 630          Sunrisers Hyderabad          Sunrisers Hyderabad         field
#
#      result  dl_applied                 winner  win_by_runs  win_by_wickets
# ...

# %%
df.dropna()
# Out:
# Empty DataFrame
# Columns: [id, season, city, date, team1, team2, toss_winner, toss_decision, result, dl_applied, winner, win_by_runs, win_by_wickets, player_of_match, venue, umpire1, umpire2, umpire3]
# Index: []

# %%
df['season']
# Out:
# 0      2017
# 1      2017
# 2      2017
# 3      2017
# 4      2017
#        ...
# 631    2016
# 632    2016
# 633    2016
# 634    2016
# 635    2016
# Name: season, Length: 636, dtype: int64

# %%
df.season
# Out:
# 0      2017
# 1      2017
# 2      2017
# 3      2017
# 4      2017
#        ...
# 631    2016
# 632    2016
# 633    2016
# 634    2016
# 635    2016
# Name: season, Length: 636, dtype: int64

# %%
# Groupby Method
df_city = df.groupby(['city'])
df_city.head()
# Out:
#       id  season       city        date                        team1
# 0      1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad  \
# 1      2    2017       Pune  2017-04-06               Mumbai Indians
# 2      3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3      4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4      5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
# ..   ...     ...        ...         ...                          ...
# 560  561    2015     Raipur  2015-05-09          Sunrisers Hyderabad
# 564  565    2015     Raipur  2015-05-12          Chennai Super Kings
# 626  627    2016     Kanpur  2016-05-19        Kolkata Knight Riders
# 627  628    2016     Raipur  2016-05-20          Sunrisers Hyderabad
# 629  630    2016     Kanpur  2016-05-21               Mumbai Indians
#
#                            team2                  toss_winner toss_decision
# ...

# %%
df_city['win_by_runs'].mean()
# Out:
# city
# Abu Dhabi         22.428571
# Ahmedabad         15.000000
# Bangalore         19.136364
# Bloemfontein       7.000000
# Cape Town         20.714286
# Centurion          6.750000
# Chandigarh        12.521739
# Chennai           14.895833
# Cuttack           10.428571
# Delhi             14.600000
# Dharamsala        31.000000
# Durban            10.600000
# East London       29.000000
# Hyderabad          9.918367
# Indore             0.000000
# Jaipur            13.939394
# Johannesburg       3.125000
# Kanpur             0.000000
# Kimberley         17.666667
# Kochi             22.000000
# Kolkata            9.622951
# Mumbai            12.964706
# Nagpur             5.000000
# Port Elizabeth    28.571429
# Pune              17.031250
# Raipur             3.500000
# Rajkot             7.000000
# Ranchi             5.857143
# Sharjah           12.333333
# Visakhapatnam     25.636364
# Name: win_by_runs, dtype: float64

# %%
# Filtering

df_sub = df[df['city']  == 'Ahmedabad']
df_sub.head()
# Out:
#       id  season       city        date             team1
# 179  180    2010  Ahmedabad  2010-03-15  Rajasthan Royals  \
# 186  187    2010  Ahmedabad  2010-03-20  Rajasthan Royals
# 194  195    2010  Ahmedabad  2010-03-26   Deccan Chargers
# 197  198    2010  Ahmedabad  2010-03-28  Rajasthan Royals
# 481  482    2014  Ahmedabad  2014-05-05  Rajasthan Royals
#
#                      team2            toss_winner toss_decision  result
# 179       Delhi Daredevils       Delhi Daredevils         field  normal  \
# 186  Kolkata Knight Riders       Rajasthan Royals           bat  normal
# 194       Rajasthan Royals        Deccan Chargers           bat  normal
# 197    Chennai Super Kings       Rajasthan Royals           bat  normal
# 481  Kolkata Knight Riders  Kolkata Knight Riders         field  normal
#
#      dl_applied            winner  win_by_runs  win_by_wickets
# 179           0  Delhi Daredevils            0               6  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 636 entries, 0 to 635
# Data columns (total 18 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               636 non-null    int64
#  1   season           636 non-null    int64
#  2   city             629 non-null    object
#  3   date             636 non-null    object
#  4   team1            636 non-null    object
#  5   team2            636 non-null    object
#  6   toss_winner      636 non-null    object
#  7   toss_decision    636 non-null    object
#  8   result           636 non-null    object
#  9   dl_applied       636 non-null    int64
#  10  winner           633 non-null    object
#  11  win_by_runs      636 non-null    int64
#  12  win_by_wickets   636 non-null    int64
#  13  player_of_match  633 non-null    object
#  14  venue            636 non-null    object
#  15  umpire1          635 non-null    object
#  16  umpire2          635 non-null    object
# ...

# %%
df[ df['season']  > 2015]
# Out:
#       id  season       city        date                        team1
# 0      1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad  \
# 1      2    2017       Pune  2017-04-06               Mumbai Indians
# 2      3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3      4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4      5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
# ..   ...     ...        ...         ...                          ...
# 631  632    2016     Raipur  2016-05-22             Delhi Daredevils
# 632  633    2016  Bangalore  2016-05-24                Gujarat Lions
# 633  634    2016      Delhi  2016-05-25          Sunrisers Hyderabad
# 634  635    2016      Delhi  2016-05-27                Gujarat Lions
# 635  636    2016  Bangalore  2016-05-29          Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision
# ...

# %%
# Slicing

df[['season', 'win_by_runs', 'team1', 'team2']]
# Out:
#      season  win_by_runs                        team1
# 0      2017           35          Sunrisers Hyderabad  \
# 1      2017            0               Mumbai Indians
# 2      2017            0                Gujarat Lions
# 3      2017            0       Rising Pune Supergiant
# 4      2017           15  Royal Challengers Bangalore
# ..      ...          ...                          ...
# 631    2016            0             Delhi Daredevils
# 632    2016            0                Gujarat Lions
# 633    2016           22          Sunrisers Hyderabad
# 634    2016            0                Gujarat Lions
# 635    2016            8          Sunrisers Hyderabad
#
#                            team2
# 0    Royal Challengers Bangalore
# 1         Rising Pune Supergiant
# 2          Kolkata Knight Riders
# 3                Kings XI Punjab
# 4               Delhi Daredevils
# ..                           ...
# 631  Royal Challengers Bangalore
# 632  Royal Challengers Bangalore
# ...

# %%
# Selecting Rows

df[10:20]
# Out:
#     id  season       city        date                        team1
# 10  11    2017    Kolkata  2017-04-13              Kings XI Punjab  \
# 11  12    2017  Bangalore  2017-04-14  Royal Challengers Bangalore
# 12  13    2017     Rajkot  2017-04-14       Rising Pune Supergiant
# 13  14    2017    Kolkata  2017-04-15        Kolkata Knight Riders
# 14  15    2017      Delhi  2017-04-15             Delhi Daredevils
# 15  16    2017     Mumbai  2017-04-16                Gujarat Lions
# 16  17    2017  Bangalore  2017-04-16       Rising Pune Supergiant
# 17  18    2017      Delhi  2017-04-17             Delhi Daredevils
# 18  19    2017  Hyderabad  2017-04-17          Sunrisers Hyderabad
# 19  20    2017     Rajkot  2017-04-18  Royal Challengers Bangalore
#
#                           team2                  toss_winner toss_decision
# 10        Kolkata Knight Riders        Kolkata Knight Riders         field  \
# 11               Mumbai Indians               Mumbai Indians         field
# ...

# %%
df.loc[10:20, ['season', 'team1', 'team2']]
# Out:
#     season                        team1                        team2
# 10    2017              Kings XI Punjab        Kolkata Knight Riders
# 11    2017  Royal Challengers Bangalore               Mumbai Indians
# 12    2017       Rising Pune Supergiant                Gujarat Lions
# 13    2017        Kolkata Knight Riders          Sunrisers Hyderabad
# 14    2017             Delhi Daredevils              Kings XI Punjab
# 15    2017                Gujarat Lions               Mumbai Indians
# 16    2017       Rising Pune Supergiant  Royal Challengers Bangalore
# 17    2017             Delhi Daredevils        Kolkata Knight Riders
# 18    2017          Sunrisers Hyderabad              Kings XI Punjab
# 19    2017  Royal Challengers Bangalore                Gujarat Lions
# 20    2017          Sunrisers Hyderabad             Delhi Daredevils

# %%
df.iloc[10:20, [0,3,4,5]]
# Out:
#     id        date                        team1                        team2
# 10  11  2017-04-13              Kings XI Punjab        Kolkata Knight Riders
# 11  12  2017-04-14  Royal Challengers Bangalore               Mumbai Indians
# 12  13  2017-04-14       Rising Pune Supergiant                Gujarat Lions
# 13  14  2017-04-15        Kolkata Knight Riders          Sunrisers Hyderabad
# 14  15  2017-04-15             Delhi Daredevils              Kings XI Punjab
# 15  16  2017-04-16                Gujarat Lions               Mumbai Indians
# 16  17  2017-04-16       Rising Pune Supergiant  Royal Challengers Bangalore
# 17  18  2017-04-17             Delhi Daredevils        Kolkata Knight Riders
# 18  19  2017-04-17          Sunrisers Hyderabad              Kings XI Punjab
# 19  20  2017-04-18  Royal Challengers Bangalore                Gujarat Lions

# %%
df.iloc[0] 
# First row of a df
# Out:
# id                                                         1
# season                                                  2017
# city                                               Hyderabad
# date                                              2017-04-05
# team1                                    Sunrisers Hyderabad
# team2                            Royal Challengers Bangalore
# toss_winner                      Royal Challengers Bangalore
# toss_decision                                          field
# result                                                normal
# dl_applied                                                 0
# winner                                   Sunrisers Hyderabad
# win_by_runs                                               35
# win_by_wickets                                             0
# player_of_match                                 Yuvraj Singh
# venue              Rajiv Gandhi International Stadium, Uppal
# ...

# %%
df.iloc[-1]
# Out:
# id                                         636
# season                                    2016
# city                                 Bangalore
# date                                2016-05-29
# team1                      Sunrisers Hyderabad
# team2              Royal Challengers Bangalore
# toss_winner                Sunrisers Hyderabad
# toss_decision                              bat
# result                                  normal
# dl_applied                                   0
# winner                     Sunrisers Hyderabad
# win_by_runs                                  8
# win_by_wickets                               0
# player_of_match                    BCJ Cutting
# venue                    M Chinnaswamy Stadium
# umpire1                        HDPK Dharmasena
# umpire2                           BNJ Oxenford
# umpire3                                    NaN
# Name: 635, dtype: object

# %%
df.iloc[:,0] #First column
# Out:
# 0        1
# 1        2
# 2        3
# 3        4
# 4        5
#       ...
# 631    632
# 632    633
# 633    634
# 634    635
# 635    636
# Name: id, Length: 636, dtype: int64

# %%
df.iloc[0:7]
# Out:
#    id  season       city        date                        team1
# 0   1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad  \
# 1   2    2017       Pune  2017-04-06               Mumbai Indians
# 2   3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3   4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4   5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
# 5   6    2017  Hyderabad  2017-04-09                Gujarat Lions
# 6   7    2017     Mumbai  2017-04-09        Kolkata Knight Riders
#
#                          team2                  toss_winner toss_decision
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field  \
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# ...

# %%
df.iloc[1:3 , 0:2]
# Out:
#    id  season
# 1   2    2017
# 2   3    2017

# %%
# Sorting

df_sorted = df.sort_values(by = 'win_by_runs', ascending = False)
df_sorted.head()
# Out:
#       id  season       city        date                        team1
# 43    44    2017      Delhi  2017-05-06               Mumbai Indians  \
# 619  620    2016  Bangalore  2016-05-14  Royal Challengers Bangalore
# 59    60    2008  Bangalore  2008-04-18        Kolkata Knight Riders
# 556  557    2015  Bangalore  2015-05-06  Royal Challengers Bangalore
# 410  411    2013  Bangalore  2013-04-23  Royal Challengers Bangalore
#
#                            team2                  toss_winner toss_decision
# 43              Delhi Daredevils             Delhi Daredevils         field  \
# 619                Gujarat Lions                Gujarat Lions         field
# 59   Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 556              Kings XI Punjab              Kings XI Punjab         field
# 410                Pune Warriors                Pune Warriors         field
#
#      result  dl_applied                       winner  win_by_runs
# ...

# %%
df_sort = df.sort_values(by = ['season', 'win_by_runs'], ascending= [True, False])
df_sort.head()
# Out:
#       id  season        city        date                  team1
# 59    60    2008   Bangalore  2008-04-18  Kolkata Knight Riders  \
# 114  115    2008      Mumbai  2008-05-30       Rajasthan Royals
# 68    69    2008  Chandigarh  2008-04-25        Kings XI Punjab
# 100  101    2008      Jaipur  2008-05-17       Rajasthan Royals
# 77    78    2008      Jaipur  2008-05-01       Rajasthan Royals
#
#                            team2                  toss_winner toss_decision
# 59   Royal Challengers Bangalore  Royal Challengers Bangalore         field  \
# 114             Delhi Daredevils             Delhi Daredevils         field
# 68                Mumbai Indians               Mumbai Indians         field
# 100  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 77         Kolkata Knight Riders             Rajasthan Royals           bat
#
#      result  dl_applied                 winner  win_by_runs  win_by_wickets
# ...
