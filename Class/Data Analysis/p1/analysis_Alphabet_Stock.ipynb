# %%
import pandas as pd

# %%
df = pd.read_csv('alphabet_stock_data.csv')

# %%
df.head()
# Out:
#          Date         Open         High          Low        Close
# 0  2020-04-01  1122.000000  1129.689941  1097.449951  1105.619995  \
# 1  2020-04-02  1098.260010  1126.859985  1096.400024  1120.839966
# 2  2020-04-03  1119.015015  1123.540039  1079.810059  1097.880005
# 3  2020-04-06  1138.000000  1194.660034  1130.939941  1186.920044
# 4  2020-04-07  1221.000000  1225.000000  1182.229980  1186.510010
#
#      Adj Close   Volume
# 0  1105.619995  2343100
# 1  1120.839966  1964900
# 2  1097.880005  2313400
# 3  1186.920044  2664700
# 4  1186.510010  2387300

# %%
import matplotlib.pyplot as plt

# %%
# 1. Write a Pandas program to create a line plot of the historical stock prices of Alphabet Inc.
# between two specific dates.

start = pd.to_datetime('2020-4-1')
end = pd.to_datetime('2020-4-30')                         
df['Date'] = pd.to_datetime(df['Date']) 
mask1 = df['Date'] >= start
mask2 = df['Date'] <= end
df1 = df[mask1]
df_new = df1[mask2]
df2 = df.loc[new_df]
df2.plot(x='Date', y=['Open'], color = ['red']);
plt.show()

# %%
# 2. Write a Pandas program to create a line plot of the opening, closing stock prices of Alphabet
# Inc. between two specific dates.

start = pd.to_datetime('2020-4-1')
end = pd.to_datetime('2020-4-30')                         
df['Date'] = pd.to_datetime(df['Date']) 
mask1 = df['Date'] >= start
mask2 = df['Date'] <= end
df1 = df[mask1]
df_new = df1[mask2]
df2 = df.loc[new_df]
df2.plot(x='Date', y=['Open', 'Close'], color = ['red', 'blue']);
plt.show()

# %%
# 3. Write a Pandas program to create a bar plot of the trading volume of Alphabet Inc. stock
# between two specific dates.

start = pd.to_datetime('2020-4-1')
end = pd.to_datetime('2020-4-30')                         
df['Date'] = pd.to_datetime(df['Date']) 
mask1 = df['Date'] >= start
mask2 = df['Date'] <= end
df1 = df[mask1]
df_new = df1[mask2]
df2 = df.loc[new_df]
df2.plot(x='Date', y=['Volume'], color = ['blue'], kind = 'bar');
plt.show()

# %%
# 4. Write a Pandas program to create a bar plot of opening, closing stock prices of Alphabet Inc.
# between two specific dates.

start = pd.to_datetime('2020-4-1')
end = pd.to_datetime('2020-4-30')                         
df['Date'] = pd.to_datetime(df['Date']) 
mask1 = df['Date'] >= start
mask2 = df['Date'] <= end
df1 = df[mask1]
df_new = df1[mask2]
df2 = df.loc[new_df]
df2.plot(x='Date', y=['Open', 'Close'], color = ['blue', 'orange'], kind = 'bar');
plt.show()

# %%
# 5. Write a Pandas program to create a bar plot of opening, closing stock prices of Alphabet Inc.
# between two specific dates.

start = pd.to_datetime('2020-4-1')
end = pd.to_datetime('2020-4-30')                         
df['Date'] = pd.to_datetime(df['Date']) 
mask1 = df['Date'] >= start
mask2 = df['Date'] <= end
df1 = df[mask1]
df_new = df1[mask2]
df2 = df.loc[new_df]
df2.plot(x='Date', y=['Open', 'Close'], color = ['blue', 'orange'], kind = 'bar', stacked = True);
plt.show()

# %%
# 6. Write a Pandas program to create a stacked histograms plot of opening, closing, high, low
# stock prices of Alphabet Inc. between two specific dates with more bins.
df3 = df2[['Open','Close','High','Low']]
df3.hist()
plt.show()

# %%
# 7. Write a Pandas program to create a stacked histograms plot with more bins of opening,
# closing, high, low stock prices of Alphabet Inc. between two specific dates.

# same as 6
df3 = df2[['Open','Close','High','Low']]
df3.hist()
plt.show()

# %% [markdown]
# 8. Write a Pandas program to create a plot of adjusted closing prices, 30 days simple moving
# average and exponential moving average of Alphabet Inc. between two specific dates.

# %% [markdown]
# 9. Write a Pandas program to plot the volatility over a period of time of Alphabet Inc. stock price
# between two specific dates.

# %% [markdown]
# 10. Write a Pandas program to create a histogram to visualize daily return distribution of
# Alphabet Inc. stock price between two specific dates.
